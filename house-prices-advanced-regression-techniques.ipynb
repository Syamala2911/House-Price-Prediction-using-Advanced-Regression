# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('C:\Users\Lenovo\Desktop\Prodigy InfoTech - Internship\Task - 1\train.csv')
# Out:
#   Cell In[2], line 1
#     df = pd.read_csv('C:\Users\Lenovo\Desktop\Prodigy InfoTech - Internship\Task - 1\train.csv')
#                      ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
final_df = df.drop(['LotShape', 'LandContour', 'LotConfig', 'Neighborhood', 'Condition2', 'YearRemodAdd', 'MasVnrType', 'BsmtQual', 'BsmtCond', 'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'Heating', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtHalfBath', 'HalfBath', 'KitchenQual', 'TotRmsAbvGrd', 'Fireplaces', 'FireplaceQu', 'GarageYrBlt', 'GarageFinish', 'GarageArea', 'GarageQual', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'MiscFeature', 'MiscVal'], axis='columns')

# %%
pd.set_option('display.max_columns', None)

# %%
final_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley Utilities  \
# 0   1          60       RL         65.0     8450   Pave   NaN    AllPub
# 1   2          20       RL         80.0     9600   Pave   NaN    AllPub
# 2   3          60       RL         68.0    11250   Pave   NaN    AllPub
# 3   4          70       RL         60.0     9550   Pave   NaN    AllPub
# 4   5          60       RL         84.0    14260   Pave   NaN    AllPub
#
#   LandSlope Condition1 BldgType HouseStyle  OverallQual  OverallCond  \
# 0       Gtl       Norm     1Fam     2Story            7            5
# 1       Gtl      Feedr     1Fam     1Story            6            8
# 2       Gtl       Norm     1Fam     2Story            7            5
# 3       Gtl       Norm     1Fam     2Story            7            5
# 4       Gtl       Norm     1Fam     2Story            8            5
#
#    YearBuilt RoofStyle RoofMatl Exterior1st Exterior2nd  MasVnrArea ExterQual  \
# ...

# %%
final_df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'Utilities', 'LandSlope', 'Condition1', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrArea', 'ExterQual',
#        'ExterCond', 'Foundation', 'BsmtExposure', 'BsmtFinType1',
#        'TotalBsmtSF', 'HeatingQC', 'CentralAir', 'Electrical', 'BsmtFullBath',
#        'FullBath', 'BedroomAbvGr', 'KitchenAbvGr', 'Functional', 'GarageType',
#        'GarageCars', 'GarageCond', 'PavedDrive', 'WoodDeckSF', 'PoolArea',
#        'PoolQC', 'Fence', 'MoSold', 'YrSold', 'SaleType', 'SaleCondition',
#        'SalePrice'],
#       dtype='object')

# %%
final_df.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# Utilities           0
# LandSlope           0
# Condition1          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtExposure       38
# BsmtFinType1       37
# TotalBsmtSF         0
# HeatingQC           0
# CentralAir          0
# Electrical          1
# BsmtFullBath        0
# FullBath            0
# BedroomAbvGr        0
# KitchenAbvGr        0
# Functional          0
# GarageType         81
# GarageCars          0
# GarageCond         81
# PavedDrive          0
# WoodDeckSF          0
# PoolArea            0
# PoolQC           1453
# ...

# %%
#BsmtExposure, BsmtFinType1, GarageType, GarageCond, PoolQC, Fence

# %%
final_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley Utilities  \
# 0   1          60       RL         65.0     8450   Pave   NaN    AllPub
# 1   2          20       RL         80.0     9600   Pave   NaN    AllPub
# 2   3          60       RL         68.0    11250   Pave   NaN    AllPub
# 3   4          70       RL         60.0     9550   Pave   NaN    AllPub
# 4   5          60       RL         84.0    14260   Pave   NaN    AllPub
#
#   LandSlope Condition1 BldgType HouseStyle  OverallQual  OverallCond  \
# 0       Gtl       Norm     1Fam     2Story            7            5
# 1       Gtl      Feedr     1Fam     1Story            6            8
# 2       Gtl       Norm     1Fam     2Story            7            5
# 3       Gtl       Norm     1Fam     2Story            7            5
# 4       Gtl       Norm     1Fam     2Story            8            5
#
#    YearBuilt RoofStyle RoofMatl Exterior1st Exterior2nd  MasVnrArea ExterQual  \
# ...

# %%
final_df = final_df.fillna(final_df.mode().iloc[0])

# %%
final_df.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
# Alley            0
# Utilities        0
# LandSlope        0
# Condition1       0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrArea       0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtExposure     0
# BsmtFinType1     0
# TotalBsmtSF      0
# HeatingQC        0
# CentralAir       0
# Electrical       0
# BsmtFullBath     0
# FullBath         0
# BedroomAbvGr     0
# KitchenAbvGr     0
# Functional       0
# GarageType       0
# GarageCars       0
# GarageCond       0
# PavedDrive       0
# WoodDeckSF       0
# PoolArea         0
# PoolQC           0
# Fence            0
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# ...

# %%
from sklearn import preprocessing

# %%
LabelEncoder = preprocessing.LabelEncoder()

# %%
columns_to_encode = ['MSZoning', 'Street', 'Alley', 'Utilities', 'LandSlope', 'Condition1', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtExposure', 'BsmtFinType1', 'HeatingQC', 'CentralAir', 'Electrical', 'Functional', 'GarageType', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'SaleType', 'SaleCondition']

# %%
final_df[columns_to_encode] = final_df[columns_to_encode].apply(LabelEncoder.fit_transform)

# %%
final_df.head()
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  Utilities  \
# 0   1          60         3         65.0     8450       1      0          0
# 1   2          20         3         80.0     9600       1      0          0
# 2   3          60         3         68.0    11250       1      0          0
# 3   4          70         3         60.0     9550       1      0          0
# 4   5          60         3         84.0    14260       1      0          0
#
#    LandSlope  Condition1  BldgType  HouseStyle  OverallQual  OverallCond  \
# 0          0           2         0           5            7            5
# 1          0           1         0           2            6            8
# 2          0           2         0           5            7            5
# 3          0           2         0           5            7            5
# 4          0           2         0           5            8            5
#
# ...

# %%
x = final_df.drop(['SalePrice'], axis='columns')

# %%
y = final_df.SalePrice

# %%
x = x.drop(['Id'], axis='columns')

# %%
x.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  Utilities  \
# 0          60         3         65.0     8450       1      0          0
# 1          20         3         80.0     9600       1      0          0
# 2          60         3         68.0    11250       1      0          0
# 3          70         3         60.0     9550       1      0          0
# 4          60         3         84.0    14260       1      0          0
#
#    LandSlope  Condition1  BldgType  HouseStyle  OverallQual  OverallCond  \
# 0          0           2         0           5            7            5
# 1          0           1         0           2            6            8
# 2          0           2         0           5            7            5
# 3          0           2         0           5            7            5
# 4          0           2         0           5            8            5
#
#    YearBuilt  RoofStyle  RoofMatl  Exterior1st  Exterior2nd  MasVnrArea  \
# ...

# %%
y.head()
# Out:
# 0    208500
# 1    181500
# 2    223500
# 3    140000
# 4    250000
# Name: SalePrice, dtype: int64

# %%
from xgboost import XGBRegressor

# %%
model = XGBRegressor(n_estimators = 1000, learning_rate=0.2, max_depth=12, random_state=1)

# %%
model.fit(x, y)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.2, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=12, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=1000, n_jobs=None,
#              num_parallel_tree=None, random_state=1, ...)

# %%
df_test = pd.read_csv('C:\Users\Lenovo\Desktop\Prodigy InfoTech - Internship\Task - 1\test.csv')

# %%
df_test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 3         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 4         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df_test = df_test.drop(['LotShape', 'LandContour', 'LotConfig', 'Neighborhood', 'Condition2', 'YearRemodAdd', 'MasVnrType', 'BsmtQual', 'BsmtCond', 'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'Heating', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtHalfBath', 'HalfBath', 'KitchenQual', 'TotRmsAbvGrd', 'Fireplaces', 'FireplaceQu', 'GarageYrBlt', 'GarageFinish', 'GarageArea', 'GarageQual', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'MiscFeature', 'MiscVal'], axis='columns')

# %%
df_test.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            4
# LotFrontage       227
# LotArea             0
# Street              0
# Alley            1352
# Utilities           2
# LandSlope           0
# Condition1          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         1
# Exterior2nd         1
# MasVnrArea         15
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtExposure       44
# BsmtFinType1       42
# TotalBsmtSF         1
# HeatingQC           0
# CentralAir          0
# Electrical          0
# BsmtFullBath        2
# FullBath            0
# BedroomAbvGr        0
# KitchenAbvGr        0
# Functional          2
# GarageType         76
# GarageCars          1
# GarageCond         78
# PavedDrive          0
# WoodDeckSF          0
# PoolArea            0
# PoolQC           1456
# ...

# %%
df_test = df_test.fillna(df_test.mode().iloc[0])

# %%
df_test.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
# Alley            0
# Utilities        0
# LandSlope        0
# Condition1       0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrArea       0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtExposure     0
# BsmtFinType1     0
# TotalBsmtSF      0
# HeatingQC        0
# CentralAir       0
# Electrical       0
# BsmtFullBath     0
# FullBath         0
# BedroomAbvGr     0
# KitchenAbvGr     0
# Functional       0
# GarageType       0
# GarageCars       0
# GarageCond       0
# PavedDrive       0
# WoodDeckSF       0
# PoolArea         0
# PoolQC           0
# Fence            0
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# dtype: int64

# %%
from sklearn import preprocessing
LabelEncoder = preprocessing.LabelEncoder()
columns_to_encode = ['MSZoning', 'Street', 'Alley', 'Utilities', 'LandSlope', 'Condition1', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtExposure', 'BsmtFinType1', 'HeatingQC', 'CentralAir', 'Electrical', 'Functional', 'GarageType', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'SaleType', 'SaleCondition']
df_test[columns_to_encode] = df_test[columns_to_encode].apply(LabelEncoder.fit_transform)

# %%
df_test1 = df_test.drop(['Id'], axis='columns')

# %%
predictions = model.predict(df_test1)

# %%
output = pd.DataFrame({'Id': df_test['Id'], 'SalePrice':predictions})
output.to_csv('submission.csv', index=False)
